# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/devulapellykushalkumarreddy/Downloads/googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
# find which app has max reviews
df.loc[df['Reviews'].max()==df["Reviews"]]
# Out:
#                          App Category  Rating Reviews Size    Installs  Type  \
# 2989  GollerCepte Live Score   SPORTS     4.2    9992  31M  1,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 2989     0       Everyone  Sports  May 23, 2018         6.5  4.1 and up

# %%
indices=df['Reviews'].sort_values(ascending=False).head().index
df.iloc[indices]
# Out:
#                                     App  Category  Rating Reviews Size  \
# 2989             GollerCepte Live Score    SPORTS     4.2    9992  31M
# 4970       Ad Block REMOVER - NEED ROOT     TOOLS     3.3     999  91k
# 2723                SnipSnap Coupon App  SHOPPING     4.2    9975  18M
# 2705                SnipSnap Coupon App  SHOPPING     4.2    9975  18M
# 3079  US Open Tennis Championships 2018    SPORTS     4.0    9971  33M
#
#         Installs  Type Price Content Rating    Genres       Last Updated  \
# 2989  1,000,000+  Free     0       Everyone    Sports       May 23, 2018
# 4970    100,000+  Free     0       Everyone     Tools  December 17, 2013
# 2723  1,000,000+  Free     0       Everyone  Shopping   January 22, 2018
# 2705  1,000,000+  Free     0       Everyone  Shopping   January 22, 2018
# 3079  1,000,000+  Free     0       Everyone    Sports       June 5, 2018
#
#      Current Ver Android Ver
# 2989         6.5  4.1 and up
# 4970         3.2  2.2 and up
# ...

# %%
df.iloc[indices]["App"]
# Out:
# 2989               GollerCepte Live Score
# 4970         Ad Block REMOVER - NEED ROOT
# 2723                  SnipSnap Coupon App
# 2705                  SnipSnap Coupon App
# 3079    US Open Tennis Championships 2018
# Name: App, dtype: object

# %%
# Find Average Rating of free and paid apps
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
a=df.groupby('Type')

# %%
for i in a:
    print(i)
# Out:
# ('0',                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN  )
# ('Free',                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# ...

# %%
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
df['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
df['Installs'].dtype
# Out:
# dtype('O')

# %%
df['Installs'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df['Installs'].astype('int')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# Eliminating + and ,
df["Installs_"]=df['Installs'].str.replace(",","")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Installs_'],
#       dtype='object')

# %%
df['Installs_']
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: Installs_, Length: 10841, dtype: object

# %%
df['Installs_1']=df['Installs_'].str.replace("+","")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Installs_1']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_1, Length: 10841, dtype: object

# %%
df['Installs_1'].dtype
# Out:
# dtype('O')

# %%
df['Installs_1'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df['Installs_1'].astype('int')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df[df["Installs_1"]=='Free']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df[df["Installs_1"]=='Free']
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
# ...

# %%
df['Installs_1']=df['Installs_1'].str.replace('Free',"0")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Installs_1'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df['Installs_1']=df['Installs_1'].astype('int')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
df['Installs_1'].dtype
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df['Installs_1'].dtype
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
# ...
