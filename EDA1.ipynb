# %%
import pandas as pd

# %%
pd.set_option("display.max_columns",None)   #for max no of columns all column shown and scrollbar is given

# %%
df=pd.read_csv('/Users/devulapellykushalkumarreddy/Downloads/googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Total no of Apps in Google Playstore
df.shape[0]
# Out:
# 10841

# %%
len(df[:])
# Out:
# 10841

# %%
# Total no of Columns in Google Playstore
df.shape[1]
# Out:
# 13

# %%
# Display Top 5 rows of DataFrame
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Display Top 5 rows of DataFrame
df[:5]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Display Top 5 rows of DataFrame
df.loc[:4]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Display Top 5 rows of DataFrame
df.iloc[:5]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Check last 3 rows of Dataset
df.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %%
df[:-4:-1][::-1]
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %%
# Find shape of Dataset
df.shape
# Out:
# (10841, 13)

# %%
# Get info about dataset total no of rows ,total no of columns ,datatypes of each column and memory required
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Get the Statistical Information about Google playstore   Descriptive Statistics
df.describe()   #only for the numerical   columns 'Rating'
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# Get the Statistical Information about Google playstore   Descriptive Statistics
df.describe(include='all')   #For all the data
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# Total no of apps whose title name contain Astrology
df[df['App'].str.contains("Astrology")]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
df[df['App'].str.contains("Astrology")]["App"]
# Out:
# 1570     Horoscopes – Daily Zodiac Horoscope and Astrology
# 1592                သိင်္ Astrology - Min Thein Kha BayDin
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, dtype: object

# %%
for ap in df[df['App'].str.contains("Astrology")]["App"]:
    print(ap)
# Out:
# Horoscopes – Daily Zodiac Horoscope and Astrology
# သိင်္ Astrology - Min Thein Kha BayDin
# iHoroscope - 2018 Daily Horoscope & Astrology

# %%
df[df['App'].str.contains("Astrology",case=False)]["App"]
# Out:
# 1570     Horoscopes – Daily Zodiac Horoscope and Astrology
# 1592                သိင်္ Astrology - Min Thein Kha BayDin
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, dtype: object

# %%
len(df[df['App'].str.contains("Astrology",case=False)]["App"])
# Out:
# 3

# %%
# Find All Apps avg rating of Google Play Store
print(round(df['Rating'].mean(),2))
# Out:
# 4.19

# %%
# Find total no of unique Category
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Find total no of unique Category
clen=df['Category'].nunique()
print("Total no of unique Category",clen)
# Out:
# total no of unique Category 34

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
for c in df['Category'].unique():
    print(c)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9

# %%
# Find which category getting highest rating
